# %% [markdown]
# <a href="https://colab.research.google.com/github/sheng-999/pandas_test/blob/main/DataFrame_Lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Introduction to DataFrame

# %% [markdown]
# ## Librairies in Python

# %% [markdown]
# Python libraries are a collection of functions.
#
# You have to use the `import` operator to use them. Below we import the Pandas library for data analysis.

# %%
import pandas as pd # pd alias is a convention

# %% [markdown]
# Now, we can access any object or functions from pandas library by using the pd alias

# %%
pd.to_datetime('2023-08-05') # we access to_datetime() pandas function
# Out:
# Timestamp('2023-08-05 00:00:00')

# %% [markdown]
# ##Create and Save a DataFrame

# %% [markdown]
# ### From a csv/excel file excel

# %% [markdown]
# Download [introduction_dataframe_data.csv](https://drive.google.com/file/d/1FDbTULmd73kvTr1fKJQ0J-4WSVlekrzi/view?usp=sharing) and import it to Google colaboratory.

# %%
df = pd.read_csv("introduction_dataframe_data.csv")
# df = pd.read_excel()

df
# Out:
#        date  store_id  item_id  price  quantity
# 0  20190101        23       67    100         2
# 1  20190101        11       87     20         3
# 2  20190103        11       56     50         1
# 3  20190105        13       87     20         5
# 4  20190107        13       56     50         2
# 5  20190111        23       56     50         3
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['store_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['item_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['price'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['store_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['item_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['price'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df, *[[['date', 'store_id'], ['store_id', 'item_id'], ['item_id', 'price'], ['price', 'quantity']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'store_id', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'item_id', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'price', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'quantity', None], **{})
# chart

# %%
df.columns
# Out:
# Index(['date', 'store_id', 'item_id', 'price', 'quantity'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.shape
# Out:
# (6, 5)

# %%
df.dtypes
# Out:
# date        object
# store_id     int64
# item_id      int64
# price        int64
# quantity     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      6 non-null      object
#  1   store_id  6 non-null      int64
#  2   item_id   6 non-null      int64
#  3   price     6 non-null      int64
#  4   quantity  6 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 368.0+ bytes

# %%
df.describe()
# Out:
#         store_id    item_id       price  quantity
# count   6.000000   6.000000    6.000000  6.000000
# mean   15.666667  68.166667   48.333333  2.666667
# std     5.750362  15.197588   29.268869  1.366260
# min    11.000000  56.000000   20.000000  1.000000
# 25%    11.500000  56.000000   27.500000  2.000000
# 50%    13.000000  61.500000   50.000000  2.500000
# 75%    20.500000  82.000000   50.000000  3.000000
# max    23.000000  87.000000  100.000000  5.000000

# %% [markdown]
# ### From a dictionnary

# %%
df = pd.DataFrame({
    "date": ["20190101", "20190101", "20190103", "20190105", "20190107", "20190111"],
    "store_id": [23, 11, 11, 13, 13, 23],
    "item_id": [67, 87, 56, 87, 56, 56],
    "price": [100, 20, 50, 20, 50, 50],
    "quantity": [2, 3, 1, 5, 2, 3]
})
df
# Out:
#        date  store_id  item_id  price  quantity
# 0  20190101        23       67    100         2
# 1  20190101        11       87     20         3
# 2  20190103        11       56     50         1
# 3  20190105        13       87     20         5
# 4  20190107        13       56     50         2
# 5  20190111        23       56     50         3
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['store_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['item_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['quantity'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['store_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['item_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['quantity'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df, *['date'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df, *[[['store_id', 'item_id'], ['item_id', 'price'], ['price', 'quantity']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df, *['store_id', 'date'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df, *['item_id', 'date'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df, *['price', 'date'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df, *['quantity', 'date'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'store_id', 'date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'item_id', 'date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'price', 'date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['date', 'quantity', 'date'], **{})
# chart

# %% [markdown]
# ### From a list of list

# %%
df = pd.DataFrame([['20190101', 23, 67, 100, 2],
       ['20190101', 11, 87, 20, 3],
       ['20190103', 11, 56, 50, 1],
       ['20190105', 13, 87, 20, 5],
       ['20190107', 13, 56, 50, 2],
       ['20190111', 23, 56, 50, 3]], columns = ["date", "store_id", "item_id", "price", "quantity"])
df
# Out:
#        date  store_id  item_id  price  quantity
# 0  20190101        23       67    100         2
# 1  20190101        11       87     20         3
# 2  20190103        11       56     50         1
# 3  20190105        13       87     20         5
# 4  20190107        13       56     50         2
# 5  20190111        23       56     50         3

# %% [markdown]
# ### Save a DataFrame on hard disk

# %%
df.to_csv("introduction_dataframe_data.csv", index=False) #index=True if you want to save the DataFrame index

# %% [markdown]
# ## Selecting with Pandas

# %% [markdown]
# Select a column

# %%
df["store_id"]
# Out:
# 0    23
# 1    11
# 2    11
# 3    13
# 4    13
# 5    23
# Name: store_id, dtype: int64

# %%
print(type(df["store_id"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df[["store_id"]])) # double brackets [] gives a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.store_id # only works if column has no space in its name
# Out:
# 0    23
# 1    11
# 2    11
# 3    13
# 4    13
# 5    23
# Name: store_id, dtype: int64

# %%
# df.rename(columns={'oldname':'newname','oldname2','newname2'})

# %% [markdown]
# Select **multiple columns**

# %%
columns_to_keep = ["store_id", "item_id", "quantity"]
df1 = df[columns_to_keep]
df1
# or without variable df[["store_id", "item_id", "quantity"]]
# Out:
#    store_id  item_id  quantity
# 0        23       67         2
# 1        11       87         3
# 2        11       56         1
# 3        13       87         5
# 4        13       56         2
# 5        23       56         3

# %% [markdown]
# ### loc & iloc

# %% [markdown]
# **loc** is to select the desired rows and columns using the index and column names

# %%
df.loc[1:3, ["store_id", "item_id"]]
# Out:
#    store_id  item_id
# 1        11       87
# 2        11       56
# 3        13       87
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['store_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['item_id'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_2, *['store_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['item_id'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_4, *[[['store_id', 'item_id']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_5, *['store_id', 'item_id', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_6, *['store_id', 'count()', None], **{})
# chart
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df.loc[:, ["store_id", "item_id"]]
# Out:
#    store_id  item_id
# 0        23       67
# 1        11       87
# 2        11       56
# 3        13       87
# 4        13       56
# 5        23       56

# %% [markdown]
# `iloc` also selects the desired rows and columns **but using the indices instead**.

# %%
df.iloc[1:4, 1:3]  # choose 1-3 rows, 1-2 columns
# Out:
#    store_id  item_id
# 1        11       87
# 2        11       56
# 3        13       87

# %%
df.iloc[:4,:3] # choose 0-4 rows, 0-3 columns
# Out:
#        date  store_id  item_id
# 0  20190101        23       67
# 1  20190101        11       87
# 2  20190103        11       56
# 3  20190105        13       87

# %%
df.iloc[[1,3,5],:3] # choose 1,3,5 rows, 0-4 columns
# Out:
#        date  store_id  item_id
# 1  20190101        11       87
# 3  20190105        13       87
# 5  20190111        23       56

# %% [markdown]
# ### Masking

# %% [markdown]
# When we want to filter the rows of a DataFrame, we use a mask.

# %%
mask_store_id_23 = (df["store_id"] == 23)  # return if the store id is 23

# %%
mask_store_id_23   # call result
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: store_id, dtype: bool

# %% [markdown]
# Then we apply this mask to keep only the lines equal to True

# %%
df_stores_id_23 = df[mask_store_id_23]
df_stores_id_23
# Out:
#        date  store_id  item_id  price  quantity
# 0  20190101        23       67    100         2
# 5  20190111        23       56     50         3

# %% [markdown]
# Multiple conditions can be combined in a mask

# %%
mask_store_id_23_item_id_56 = (df["store_id"] == 23) & (df["item_id"] == 56)
df[mask_store_id_23_item_id_56]
# Out:
#        date  store_id  item_id  price  quantity
# 5  20190111        23       56     50         3

# %% [markdown]
# & means "and", | means "or"
#
# Use brackets () to apply logic order

# %% [markdown]
# ## Create new columns

# %% [markdown]
# Similar to dictionaries, a new column is created by referring to it even if it does not yet exist!

# %%
df["my_1_column"] = 1

# %%
df
# Out:
#        date  store_id  item_id  price  quantity  my_1_column
# 0  20190101        23       67    100         2            1
# 1  20190101        11       87     20         3            1
# 2  20190103        11       56     50         1            1
# 3  20190105        13       87     20         5            1
# 4  20190107        13       56     50         2            1
# 5  20190111        23       56     50         3            1

# %% [markdown]
# ### Arithmetic operations

# %%
df["total_spend"] = df["quantity"] * df["price"]
df
# Out:
#        date  store_id  item_id  price  quantity  my_1_column  total_spend
# 0  20190101        23       67    100         2            1          200
# 1  20190101        11       87     20         3            1           60
# 2  20190103        11       56     50         1            1           50
# 3  20190105        13       87     20         5            1          100
# 4  20190107        13       56     50         2            1          100
# 5  20190111        23       56     50         3            1          150

# %% [markdown]
# ### Lambda functions

# %% [markdown]
# Not everything can be written with simple operations between columns, for this we need lambda functions.
#
# To illustrate a lambda function to multiply the quantity column by 2:

# %%
df['quantity']
# Out:
# 0    2
# 1    3
# 2    1
# 3    5
# 4    2
# 5    3
# Name: quantity, dtype: int64

# %%
df["quantity"].apply(lambda x: x*2) # create a new set of values without re-assigning
# Out:
# 0     4
# 1     6
# 2     2
# 3    10
# 4     4
# 5     6
# Name: quantity, dtype: int64

# %%
df['quantity'].apply(lambda x: x/7) # create a set of values x/7
# Out:
# 0    0.285714
# 1    0.428571
# 2    0.142857
# 3    0.714286
# 4    0.285714
# 5    0.428571
# Name: quantity, dtype: float64

# %% [markdown]
# It can also be applied to several columns to create a new column:

# %%
df["store_item"] = df[["store_id", "item_id"]].apply(lambda row: str(row["store_id"]) + "-" + str(row["item_id"]),
                                                     axis=1)
df
# Out:
#        date  store_id  item_id  price  quantity  my_1_column  total_spend  \
# 0  20190101        23       67    100         2            1          200
# 1  20190101        11       87     20         3            1           60
# 2  20190103        11       56     50         1            1           50
# 3  20190105        13       87     20         5            1          100
# 4  20190107        13       56     50         2            1          100
# 5  20190111        23       56     50         3            1          150
#
#   store_item
# 0      23-67
# 1      11-87
# 2      11-56
# 3      13-87
# 4      13-56
# 5      23-56

# %% [markdown]
# As many possibilities as you want / need, it's code !

# %% [markdown]
# ### With classic Python

# %%
df[['store_id','item_id']].values
# Out:
# array([[23, 67],
#        [11, 87],
#        [11, 56],
#        [13, 87],
#        [13, 56],
#        [23, 56]])

# %%
col = []

for store_id, item_id in df[["store_id", "item_id"]].values:
    col.append(str(store_id) + "-" + str(item_id))

df["store_item"] = col
df

# use for loop to append a default list, then assign the list
# Out:
#        date  store_id  item_id  price  quantity  my_1_column  total_spend  \
# 0  20190101        23       67    100         2            1          200
# 1  20190101        11       87     20         3            1           60
# 2  20190103        11       56     50         1            1           50
# 3  20190105        13       87     20         5            1          100
# 4  20190107        13       56     50         2            1          100
# 5  20190111        23       56     50         3            1          150
#
#   store_item
# 0      23-67
# 1      11-87
# 2      11-56
# 3      13-87
# 4      13-56
# 5      23-56

# %% [markdown]
# ## Agregation operations

# %% [markdown]
# Simple calculation of statistics:
#
# - sum: to calculate the sum
# - max: to calculate the maximum
# - min: to calculate the minimum
# - median: to calculate the median
# - mode: to calculate the most present value
# - nunique: to calculate the number of unique values

# %%
df["quantity"].sum()
# Out:
# 16

# %% [markdown]
# Average price

# %%
df["price"].sum() / df["quantity"].sum()
# Out:
# 18.125

# %% [markdown]
# Differentiate functions per column

# %%
df.agg({"price": "mean", "quantity": "median"})
# agg parameter is a dictionary with the name of the column as the key and the function to be applied as the value
# Out:
# price       48.333333
# quantity     2.500000
# dtype: float64

# %% [markdown]
# ### Groupby

# %% [markdown]
# Use Groupby to resume info per dimension. In the following example, we calculate the total quantity per store.

# %%
# sum
df.groupby(["store_id"])["quantity"].sum()
# Out:
# store_id
# 11    4
# 13    7
# 23    5
# Name: quantity, dtype: int64

# %% [markdown]
# Get the average for quantity and price at the same time.
#
# Note, we don't need to use `.agg()` here because it's the same function we want apply.

# %%
#
df.groupby(["store_id"])["quantity", "price"].mean()
# Out:
# <ipython-input-58-feaf3443623f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["store_id"])["quantity", "price"].mean()
#           quantity  price
# store_id
# 11             2.0   35.0
# 13             3.5   35.0
# 23             2.5   75.0

# %% [markdown]
# You may also want to sort the output, you will need to use the `sort_values` function

# %%
# average of qty & price by id
# sort by values qty
df.groupby(["store_id"])["quantity", "price"].mean().sort_values(by=["quantity"], ascending=[False])
# Out:
# <ipython-input-60-8d30af91144d>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["store_id"])["quantity", "price"].mean().sort_values(by=["quantity"], ascending=[False])
#           quantity  price
# store_id
# 13             3.5   35.0
# 23             2.5   75.0
# 11             2.0   35.0

# %% [markdown]
# ### Pivot table

# %% [markdown]
# Pivot tables are very useful in Excel, Pandas also offers the possibility to do it easily

# %%
df
# Out:
#        date  store_id  item_id  price  quantity  my_1_column  total_spend  \
# 0  20190101        23       67    100         2            1          200
# 1  20190101        11       87     20         3            1           60
# 2  20190103        11       56     50         1            1           50
# 3  20190105        13       87     20         5            1          100
# 4  20190107        13       56     50         2            1          100
# 5  20190111        23       56     50         3            1          150
#
#   store_item
# 0      23-67
# 1      11-87
# 2      11-56
# 3      13-87
# 4      13-56
# 5      23-56

# %%
df_pivot = pd.pivot_table(df, values=['quantity'], index=['item_id'], columns=['store_id'], aggfunc=sum)
df_pivot
# Out:
#          quantity
# store_id       11   13   23
# item_id
# 56            1.0  2.0  3.0
# 67            NaN  NaN  2.0
# 87            3.0  5.0  NaN

# %%
df_pivot.columns
# Out:
# MultiIndex([('quantity', 11),
#             ('quantity', 13),
#             ('quantity', 23)],
#            names=[None, 'store_id'])

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 56 to 87
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (quantity, 11)  2 non-null      float64
#  1   (quantity, 13)  2 non-null      float64
#  2   (quantity, 23)  2 non-null      float64
# dtypes: float64(3)
# memory usage: 96.0 bytes

# %% [markdown]
# ### Melting

# %% [markdown]
# Delete quantity column index and integrate item_id as a column

# %%
df_pivot.columns = df_pivot.columns.droplevel(0)
df_pivot = df_pivot.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-7b4186f045fe> in <cell line: 1>()
# ----> 1 df_pivot.columns = df_pivot.columns.droplevel(0)
#       2 df_pivot = df_pivot.reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in droplevel(self, level)
#    2180         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    2181
# -> 2182         return self._drop_level_numbers(levnums)
#    2183
#    2184     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _drop_level_numbers(self, levnums)
#    2191             return self
#    2192         if len(levnums) >= self.nlevels:
# -> 2193             raise ValueError(
#    2194                 f"Cannot remove {len(levnums)} levels from an index with "
#    2195                 f"{self.nlevels} levels: at least one level must be left."
#
# ValueError: Cannot remove 1 levels from an index with 1 levels: at least one level must be left.

# %%
df_pivot
# Out:
# store_id  item_id   11   13   23
# 0              56  1.0  2.0  3.0
# 1              67  NaN  NaN  2.0
# 2              87  3.0  5.0  NaN

# %% [markdown]
# Melting let you do the opposite action of pivoting. For example we want to create an extra column with store_ids.

# %%
pd.melt(df_pivot, id_vars=["item_id"], value_vars=[11, 13, 23])
# Out:
#    item_id store_id  value
# 0       56       11    1.0
# 1       67       11    NaN
# 2       87       11    3.0
# 3       56       13    2.0
# 4       67       13    NaN
# 5       87       13    5.0
# 6       56       23    3.0
# 7       67       23    2.0
# 8       87       23    NaN

# %% [markdown]
# ## Joins

# %% [markdown]
# ### Concatenate

# %%
df1 = pd.DataFrame({"id": [100, 101, 102],
                    "first_name": ["paul", "victor", "lucie"],
                    "last_name": ["oiseau", "blanc", "misa"]})
df1
# Out:
#     id first_name last_name
# 0  100       paul    oiseau
# 1  101     victor     blanc
# 2  102      lucie      misa

# %%
df2 = pd.DataFrame({"id": [103, 104, 105],
                    "first_name": ["cécile", "ludivine", "kevin"],
                    "last_name": ["hevert", "masseau", "leroi"]})
df2
# Out:
#     id first_name last_name
# 0  103     cécile    hevert
# 1  104   ludivine   masseau
# 2  105      kevin     leroi

# %% [markdown]
# To concatenate two DataFrames, you need to use the `concat` function of pandas, **beware** of the axis parameter, which determines how to concatenate (in rows or columns)

# %%
df_concat = pd.concat([df1, df2], axis=0)
df_concat
# Out:
#     id first_name last_name
# 0  100       paul    oiseau
# 1  101     victor     blanc
# 2  102      lucie      misa
# 0  103     cécile    hevert
# 1  104   ludivine   masseau
# 2  105      kevin     leroi

# %% [markdown]
# Reordering the names of the indices

# %%
df_concat = df_concat.reset_index(drop=True)
df_concat
# Out:
#     id first_name last_name
# 0  100       paul    oiseau
# 1  101     victor     blanc
# 2  102      lucie      misa
# 3  103     cécile    hevert
# 4  104   ludivine   masseau
# 5  105      kevin     leroi

# %%
pd.concat([df1, df2], axis=1) # With opposite axis
# Out:
#     id first_name last_name   id first_name last_name
# 0  100       paul    oiseau  103     cécile    hevert
# 1  101     victor     blanc  104   ludivine   masseau
# 2  102      lucie      misa  105      kevin     leroi

# %% [markdown]
# ### join

# %%
df3 = pd.DataFrame({"id": [103, 100, 101, 112],
                    "age": [28, 42, 87, 55]})
df3
# Out:
#     id  age
# 0  103   28
# 1  100   42
# 2  101   87
# 3  112   55

# %% [markdown]
# **Inner join**, keep only the ids common to both DataFrame

# %%
pd.merge(df_concat, df3, on=["id"], how="inner") # you can have multiple columns
# Out:
#     id first_name last_name  age
# 0  100       paul    oiseau   42
# 1  101     victor     blanc   87
# 2  103     cécile    hevert   28

# %% [markdown]
# **Left join**, keep only the ids of the left DataFrame and we mark the correspondence if there is one!

# %%
pd.merge(df_concat, df3, on=["id"], how="left")
# Out:
#     id first_name last_name   age
# 0  100       paul    oiseau  42.0
# 1  101     victor     blanc  87.0
# 2  102      lucie      misa   NaN
# 3  103     cécile    hevert  28.0
# 4  104   ludivine   masseau   NaN
# 5  105      kevin     leroi   NaN

# %% [markdown]
# **Outer join**, keep the union of the ids of the left and right DataFrame with correspondence when it is possible

# %%
pd.merge(df_concat, df3, on=["id"], how="outer")
# Out:
#     id first_name last_name   age
# 0  100       paul    oiseau  42.0
# 1  101     victor     blanc  87.0
# 2  102      lucie      misa   NaN
# 3  103     cécile    hevert  28.0
# 4  104   ludivine   masseau   NaN
# 5  105      kevin     leroi   NaN
# 6  112        NaN       NaN  55.0

# %% [markdown]
# ## Handling dates in Pandas

# %% [markdown]
# Let's look at the type of the date column of the sales data

# %%
print(df.loc[0, "date"])
type(df.loc[0, "date"])
# Out:
# 20190101
# str

# %% [markdown]
# You can convert a column to date format using functions already implemented in Python.

# %%
df["date"] = pd.to_datetime(df["date"], format='%Y%m%d') # format depends on how is written your date!

# %%
print(df.loc[0, "date"])
type(df.loc[0, "date"])
# Out:
# 2019-01-01 00:00:00
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# List of the columns and their corresponding types. Date column is now datetime64 format.

# %%
df.dtypes
# Out:
# date           datetime64[ns]
# store_id                int64
# item_id                 int64
# price                   int64
# quantity                int64
# my_1_column             int64
# total_spend             int64
# store_item             object
# dtype: object

# %% [markdown]
# To access to dates attributes, you need to use `.dt` on your date column:

# %%
df["date"].dt.day #.month .year
# Out:
# 0     1
# 1     1
# 2     3
# 3     5
# 4     7
# 5    11
# Name: date, dtype: int64

# %% [markdown]
# It is now very easy to create another column containing the year week of the dates

# %%
df["date-year-week"] = df["date"].dt.strftime("%Y-%U")
df
# Out:
#         date  store_id  item_id  price  quantity  my_1_column  total_spend  \
# 0 2019-01-01        23       67    100         2            1          200
# 1 2019-01-01        11       87     20         3            1           60
# 2 2019-01-03        11       56     50         1            1           50
# 3 2019-01-05        13       87     20         5            1          100
# 4 2019-01-07        13       56     50         2            1          100
# 5 2019-01-11        23       56     50         3            1          150
#
#   store_item date-year-week
# 0      23-67        2019-00
# 1      11-87        2019-00
# 2      11-56        2019-00
# 3      13-87        2019-00
# 4      13-56        2019-01
# 5      23-56        2019-01

# %% [markdown]
# You have plenty functions accessible with `.dt`, you can find them [on this webpage](https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.html).

# %% [markdown]
# # Let's code !
